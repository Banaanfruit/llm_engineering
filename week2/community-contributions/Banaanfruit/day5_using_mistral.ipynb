# %% [markdown]
# # Project - Airline AI Assistant
#
# We'll now bring together what we've learned to make an AI Customer Support assistant for an Airline

# %%
# imports

import os
import json
from dotenv import load_dotenv
from mistralai.client import Mistral
import gradio as gr
import sqlite3

# %%
# Initialization

load_dotenv(override=True)

mistral_api_key = os.getenv('MISTRAL_API_KEY')
if mistral_api_key:
    print(f"Mistral API Key exists and begins {mistral_api_key[:8]}")
else:
    print("Mistral API Key not set")
    
MODEL = "mistral-small-2603"
Mistral= Mistral(api_key=mistral_api_key)

DB = "prices.db"
# Out:
# Mistral API Key exists and begins qsF5gGNR

# %%
system_message = """
You are a helpful assistant for an Airline called FlightAI.
Give short, courteous answers, no more than 1 sentence.
Always be accurate. If you don't know the answer, say so.
"""

# %%
def get_ticket_price(city):
    print(f"DATABASE TOOL CALLED: Getting price for {city}", flush=True)
    with sqlite3.connect(DB) as conn:
        cursor = conn.cursor()
        cursor.execute('SELECT price FROM prices WHERE city = ?', (city.lower(),))
        result = cursor.fetchone()
        return f"Ticket price to {city} is ${result[0]}" if result else "No price data available for this city"

# %%
get_ticket_price("Paris")
# Out:
# DATABASE TOOL CALLED: Getting price for Paris
# 'Ticket price to Paris is $899.0'

# %%
price_function = {
    "name": "get_ticket_price",
    "description": "Get the price of a return ticket to the destination city.",
    "parameters": {
        "type": "object",
        "properties": {
            "destination_city": {
                "type": "string",
                "description": "The city that the customer wants to travel to",
            },
        },
        "required": ["destination_city"],
        "additionalProperties": False
    }
}
tools = [{"type": "function", "function": price_function}]
tools
# Out:
# [{'type': 'function',
#   'function': {'name': 'get_ticket_price',
#    'description': 'Get the price of a return ticket to the destination city.',
#    'parameters': {'type': 'object',
#     'properties': {'destination_city': {'type': 'string',
#       'description': 'The city that the customer wants to travel to'}},
#     'required': ['destination_city'],
#     'additionalProperties': False}}}]

# %%
def chat(message, history):
    history = [{"role": h["role"], "content": h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = Mistral.chat.complete(model=MODEL, messages=messages)
    return response.choices[0].message.content

gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
def chat(message, history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history + [{"role": "user", "content": message}]
    response = Mistral.chat.complete(model=MODEL, messages=messages, tools=tools)

    while response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        responses = handle_tool_calls(message)
        messages.append(message)
        messages.extend(responses)
        response = Mistral.chat.complete(model=MODEL, messages=messages, tools=tools)
    
    return response.choices[0].message.content

# %%
def handle_tool_calls(message):
    responses = []
    for tool_call in message.tool_calls:
        if tool_call.function.name == "get_ticket_price":
            arguments = json.loads(tool_call.function.arguments)
            city = arguments.get('destination_city')
            price_details = get_ticket_price(city)
            responses.append({
                "role": "tool",
                "content": price_details,
                "tool_call_id": tool_call.id
            })
    return responses

# %%
gr.ChatInterface(fn=chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A bit more about what Gradio actually does:
#
# 1. Gradio constructs a frontend Svelte app based on our Python description of the UI
# 2. Gradio starts a server built upon the Starlette web framework listening on a free port that serves this React app
# 3. Gradio creates backend routes for our callbacks, like chat(), which calls our functions
#
# And of course when Gradio generates the frontend app, it ensures that the the Submit button calls the right backend route.
#
# That's it!
#
# It's simple, and it has a result that feels magical.

# %% [markdown]
# # Let's go multi-modal!!
#
# We can use DALL-E-3, the image generation model behind GPT-4o, to make us some images
#
# Let's put this in a function called artist.
#
# ### Price alert: each time I generate an image it costs about 4 cents - don't go crazy with images!

# %%
# Some imports for handling images

import base64
import requests
from pathlib import Path
from io import BytesIO
from PIL import Image
import ast

# %%
image_agent = Mistral.beta.agents.create(
    model="mistral-medium-latest",
    name="Image Generation Agent",
    description="Agent used to generate images.",
    instructions="Use the image generation tool when you have to create images.",
    tools=[{"type": "image_generation"}],
    completion_args={
        "temperature": 0.3,
        "top_p": 0.95,
    }
)

# %%
def artist(city):
    # Mistral will output the image as an url.
    image_response = Mistral.beta.conversations.start(
            agent_id=image_agent.id,
            inputs=f"An image representing a vacation in {city}, showing tourist spots and everything unique about {city}, in a vibrant pop-art style",

        )
    url = ast.literal_eval(image_response.outputs[0].info['result'])['url']
    image = Image.open(requests.get(url, stream=True).raw)

    return image

# %%
image = artist("Breda")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768>

# %%
def talker(message):
    response = Mistral.audio.speech.complete(
      model="voxtral-mini-tts-2603",
      voice_id="e90ce106-8ce1-401f-ab90-cde11dbaca80",
      input= message,
      response_format='mp3'
    )

    Path("output.mp3").write_bytes(base64.b64decode(response.audio_data))
    print("Saved to output.mp3")
    return base64.b64decode(response.audio_data)

# %%
talker('hello')
# Out:
# Saved to output.mp3
# b'ID3\x04\x00\x00\x00\x00\x00"TSSE\x00\x00\x00\x0e\x00\x00\x03Lavf61.7.100\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xff\xf3\xa0\xc4\x00\x0e\x89\x06e\x9e\x18FP\x00\x80\xa5\x88/\xf7\x801o\x11\x11\x11\xe3q\x8d\xc8\n7\xf5\xeb\xb9\xfa\x15w=\x11\xdf\xdc\xff\xe2\'\xfa8\x19\xfe 9\xfc\x82\xf4\x7f\xc7;\xcaO\xd6\\\xfe\'\xff\xfe\'\xff\'\xe0\x83\xbf\x0f\xaa!\xd2\x1b\x8d\xd5O\xda\xdb\x11\x13!*\x991h\xea2\xb7L9D\x03\r\xa2%U\x83\x92\xf1+\xb1\xc5e\x99;fpE&\xaa\x7fr4\xdb\x99JM>\xa1RP\xa9\xf0Qk\x96\x88\x16]Q\x97\n\xe7[\xaf\xf3\x16\x0c>\n\x9d\x84\xecq!=\x01\x1d\x04\xbc\x08\xe0l\xd7\xdc\xdf?\xf2\x91\xcd\x0b\x94\xb1T\xe4\'\xee\xe7\r;\xb6\xb5\xd7\xdc\xef!\x12\x8d\xa3\xa9\xce\xa2\xa8#\xb7\xf6\x0e#q\x11\x000\xbf\xf337\xec\xb4!Z\xfes\xfd6\x84\xd5Th@2&\xd6\x17\xebk\xf07\x89\x98\x01\xa1h,f\xdb\x1b\x12P[\r\xd8M\xe8y\xc9\x05\xfa2\xf0eK\x9do"\xe1\xe5%\x9e\xb8\xc6\xbe)JM\x0e[\xee\xfb\xbek\xbbf\xffW\x81\xac\xc3\xb3\xc1\xdeE\x8b\x894\\\xc5g\x1a%t\rG\xe2\xc4!\xb3S?\xf3wJ\x9b\x97\xd7<\xbe\xeb|C\x0f\xa4\x8dH\xf7nmvH&d\x01\xff\xf3`\xc4\xf1!\xcb\x16n^H\xc5\x8d$6,\xb3\x84\xc6h1B[\xe8\xfdC\xa2i\xa7\xfd\xfb\xbf\xfd\xb5*]\xaa\x92\x1b\xe2\x9f\xff\xd3\xd7\xfd\xf3\xc2\xe7\xdcYH\xc2\xf1\x18\xb6G\xb2\xc7Y\xa1\xeeE^\xf9\xe5\xf9\x19\x07\x16\xc8,\xeeB\xecJr\xa4+\x95\x8a\x10b&\x8cxc2\xdc\xc3{\xeb\xb0\x8cfg\xb3\xe9\x99\x1e\x86[\x90\x1e(\xb8bBAP\x0ebR\x19\x91\xc5\xa6H\x12\x18P\x18\x04\t\x82\x81\xf0\xd0\x88\x06\x0e\t\xa1=a\x91=\x97\xb9r\xf8\r\xc0\x87 \x07R\xc47\x94\xa28\xd7\'&\x1f\xc9\xff\xf3p\xc4\xf8+\xbc\x0ev\xfez\xc7\x95\xfb\x96\x1b\x82><\x91ge\x89\xaaE\xa9z\xe5\x8c\xe9\xed\xe7I\x18\x8c^\xaf\xda\xf6\xeb\xb6U\x8e\x8d{\x94X\xa8L\xa2\xb5\x8b\x16,\xcam\xe6\x94ab\xcd}\xb5\x8f\xd0\xba\x0c\xd5\xa4\xeb7j\xde\x94\xe7\xe6\x8cd\xd6\x13\xfa9[@\x05-O\xc5M\x1e\xd0\x82\x14\xfd\xf54O\xfb\xff\xff\xe4y1r\xa6\xf3/\xeb\xe1\x13\x04#=\xea\xd9\xb2\x99\x84\x04C;\xbe\xedo\xe5G\x97e\xd5\xe0\x00D\x00\t\x82\x03\x81\x04!P\xe3;;\xc7<A\xc4\xd0\x01*\x19\x8a\x00/JD^\xd8\xdaz\xbff\x15/G\x17\x19\x86a\rf\x95\xb3&\x96\x0e\xe6\x04\n\xe6\xd27\xff\xf3\x80\xc4\xf24T\x12\x8e\xfe\xe3\x07\x88\x06\x10\x1ef#\x00FE+\xee\x9c\xc1\x82\x00\x10T\x00_`\xa1\x9d)\x04@\x19X\x1a\xd0\xe2&\x16\x80k\x1c\x90\n"\x08\x10\x96\xa9\n.\x83\x00\x0f&\x0c\xb6<\xa1\xec\x01%\x14\xb1\x8c\x19\xa3\xaa\xa9\x84P\xdd)Va\x00\t\x06[\x1cs%7ng\x017\x94\xacn\xc5\xc6\x02\xd9\xed\x88\xcdt\x95\x8c\x80\xa6`\xe6\xb4\xf5UP\x01Q\x1b\x93MO\xb6\x7fze\xe5\xa0f\xef;\xe9\xc9\x98\xdbP\xb0\xd9_\x89b\xb7\xc1\xb4h$\x81\xe1\x99<\xba\x02R\x87I\xdd\x8bA2\xd8\x9c\xd5-x6\x19\x9f\xa1\x7f\x99\xa3\xc2\xa6\x08\x13\x03jR\xad\xd1=\x1c\xef\x9b?\xf8\xf4\x0e\xfa\x92s\xfe{\xbf\xc2\xf7\xd5\xae\xd7\xd6Z\x8d\x05\xd4(\xca\x82S\xeb\n\x17\xff\xf3\xa0\xc4\xe3FS\xde\x86\xfe\xeeR\xfd$\x15\x97\x12\xbf\xa6\xd1\x03\xbdr$\x13M\x04\x98JM\x92\x88\x990m\xc7\x08\x89\x1c\x8eu\xe1q\xba\xa8J\x12\xfa\xa5c\xd3[c\x8d4\xa1\x1a<0\xbf3N\xb4\x02\xfcM\xcc*\x11\xa8A\x19\xe2N\xabt\x02\xf6\r\x00\xfb\x95G\xbb\xf2\xc0\xa8\xc2!Q\x81\x80W+\x8f\x07\xbd\x0c\x02\x98f\xe4\xa0e\x85\xa6\x80\xebm\x1a\x96[\ny\xf8\xf0I\x9e\x15\xa8}\x04\xa1\x1a\x1d\xd4\x0e\xd5\x895<Gqp\xfbc\x83\xb7\xd3\xa8\xfb\x8c\xc9\x02h\x0e8%\x03\x17\xc8\'g\x02\x1dT\x18\'\xc5\xd4\xc4\x91\xfcy\xcae\xb5\xaf\x10\xcb\n\x0b\x9e\xcb?\xcd\xd6\xb5\x99\xb5w/H:\x03\x98\x8e\x0ed\xbe\x80\xe5O\xb9-\xad\x96\xdd\xed\x9a\xcbs\xc5\x17\xf3\xff\xff\xf4\xd3Kr\xe3D\x8a\xf4#B\xcf\x86_a\x91\xc3\xe1\xc6\xcf\xd5\xbb3r\xd7\x8f\x0f\xd7\x15?\xbd\x89\xd6\xe5!t;\x80\x0b\xd3\x15U B \x003\xe9-\xb8\x14:!\xf5aJ\x82\x15p\x84\x96\xa6\xb0\x08\x87J\xa1\xea1PDB\xb0\xddy\xe0X\xe3\x83fn\x1e\xc8\xbaR \x8d\xa7\xed\x1b*\xc1\x14\x0b\xa1\x8cb\xbc\xb6\xb7\xcd\xaan7\x92\x8d\xac\xff\xf3p\xc4\xf5,\xcb\xda\x98\xfe\xd3\x07\x1d\x14\x15\x84Hu\xb4\xa0\xdc\x14\x85\xdca_\xd4+\'\x19\xcdR\xaeD\xb7u\xf1\x16\xf4\xf4\xe2o\xb0&\x1c1\x83\xec\x94\xbfM\xf7]\xce\x0c\xee\xff\xcf\xe7\xcez\x9d\xc4\xcc\xde)\x04U6\xa4Y\xa7\xff\xfd)\xb1\xe4\xe4\xc8\x95\x9c\x8c\xf2[\xc9\x91\x12C>o\xe8^\xb6\xd8\x18\x19\xdaK\x98e\xc61k\xf1\x10D%\xbf\xd7\xe4\xf4\x85\xe0\xa3\x8fR\xeb\xde1`\xd5[\x04Z\xd2\xaa\xbf+!\'\xe2\x8c\xfeG\xc6a=\xa8\x13\xb8g\x11\xd9 ...

# %%
MODEL
# Out:
# 'mistral-small-2603'

# %% [markdown]
# ## Let's bring this home:
#
# 1. A multi-modal AI assistant with image and audio generation
# 2. Tool callling with database lookup
# 3. A step towards an Agentic workflow

# %%
def chat(history):
    history = [{"role":h["role"], "content":h["content"]} for h in history]
    messages = [{"role": "system", "content": system_message}] + history
    response = Mistral.chat.complete(model=MODEL, messages=messages, tools=tools)
    cities = []
    image = None

    while response.choices[0].finish_reason=="tool_calls":
        message = response.choices[0].message
        responses, cities = handle_tool_calls_and_return_cities(message)
        messages.append(message)
        messages.extend(responses)
        response = Mistral.chat.complete(model=MODEL, messages=messages, tools=tools)

    reply = response.choices[0].message.content
    history += [{"role":"assistant", "content":reply}]

    voice = talker(reply)

    if cities:
        image = artist(cities[0])
    
    return history, voice, image

# %%
def handle_tool_calls_and_return_cities(message):
    responses = []
    cities = []
    for tool_call in message.tool_calls:
        if tool_call.function.name == "get_ticket_price":
            arguments = json.loads(tool_call.function.arguments)
            city = arguments.get('destination_city')
            cities.append(city)
            price_details = get_ticket_price(city)
            responses.append({
                "role": "tool",
                "content": price_details,
                "tool_call_id": tool_call.id
            })
    return responses, cities

# %% [markdown]
# ## The 3 types of Gradio UI
#
# `gr.Interface` is for standard, simple UIs
#
# `gr.ChatInterface` is for standard ChatBot UIs
#
# `gr.Blocks` is for custom UIs where you control the components and the callbacks

# %%
# Callbacks (along with the chat() function above)

def put_message_in_chatbot(message, history):
        return "", history + [{"role":"user", "content":message}]

# UI definition

with gr.Blocks() as ui:
    with gr.Row():
        chatbot = gr.Chatbot(height=500, type="messages")
        image_output = gr.Image(height=500, interactive=False)
    with gr.Row():
        audio_output = gr.Audio(autoplay=True)
    with gr.Row():
        message = gr.Textbox(label="Chat with our AI Assistant:")

# Hooking up events to callbacks

    message.submit(put_message_in_chatbot, inputs=[message, chatbot], outputs=[message, chatbot]).then(
        chat, inputs=chatbot, outputs=[chatbot, audio_output, image_output]
    )

ui.launch(inbrowser=True, auth=("ed", "bananas"))
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Saved to output.mp3

# %% [markdown]
# # Exercises and Business Applications
#
# Add in more tools - perhaps to simulate actually booking a flight. A student has done this and provided their example in the community contributions folder.
#
# Next: take this and apply it to your business. Make a multi-modal AI assistant with tools that could carry out an activity for your work. A customer support assistant? New employee onboarding assistant? So many possibilities! Also, see the week2 end of week Exercise in the separate Notebook.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">I have a special request for you</h2>
#             <span style="color:#090;">
#                 My editor tells me that it makes a HUGE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. If you're able to take a minute to rate this, I'd be so very grateful! And regardless - always please reach out to me at ed@edwarddonner.com if I can help at any point.
#             </span>
#         </td>
#     </tr>
# </table>
